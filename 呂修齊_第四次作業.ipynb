# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 第一題：抽點系統
# ## 老師想做一個抽點系統, 也就是按一個鍵就抽一位同學出來。某班同學有大雄、胖虎、小夫、宜靜、小杉。
# ### 請幫老師寫個點名系統。

# %%
from ipywidgets import interact
from ipywidgets import interact_manual

# %%
classmate=["大雄","胖虎","小夫","宜靜","小杉"]
def select():
    print(np.random.choice(classmate,1))

# %%
interact_manual(select)
# Out:
# interactive(children=(Button(description='Run Interact', style=ButtonStyle()), Output()), _dom_classes=('widge…
# <function __main__.select()>

# %% [markdown]
# # 第二題：變長變短
# ## 做一個數值滑桿, 數字變大某個 bar 就變長或變短。
# ### bar = "■"

# %%
def bar(n):
    print("■"*n)

# %%
interact(bar,n=(0,40))
# Out:
# interactive(children=(IntSlider(value=20, description='n', max=40), Output()), _dom_classes=('widget-interact'…
# <function __main__.bar(n)>

# %% [markdown]
# # 第三題：
# ## 定義一個函數，使用interact的功能改變函數裡的變數，並將圖畫出來，讓圖片隨著數值滑桿變動

# %%
def pic(n):
    x=np.linspace(0,20,100)
    y=x**2-n**2
    plt.plot(x,y)
    y=-x**2++n**2
    plt.plot(x,y)

# %%
circle(2)

# %%
interact(pic,n=(0,100))
# Out:
# interactive(children=(IntSlider(value=50, description='n'), Output()), _dom_classes=('widget-interact',))
# <function __main__.pic(n)>

# %% [markdown]
# # 挑戰題一：考試加權分數

# %%
grades=np.array([86.5, 79.4, 88.2, 96.5, 86.3, 76.8, 96.1, 78.5, 82.4, 88.6])

# %%
c={
"土語系": [2, 2, 0, 1, 0, 0, 0, 1, 1, 0],
"財政系": [1, 1.5, 0, 1.5, 0, 0, 0, 0, 0, 0],
"金融系": [1, 1.5, 0, 2, 0, 0, 0, 0, 0, 0],
"國貿系": [1.5, 2, 0, 2, 0, 0, 0, 0, 0, 0],
"會計系": [1.5, 2, 0, 2, 0, 0, 0, 1, 1, 0],
"法律系": [1, 2, 0, 1, 0, 0, 0, 1, 0, 1],
"公行系": [1, 1.5, 0, 1.25, 0, 0, 0, 0, 0, 1.25],
"應數系": [1, 1, 1.5, 0, 1, 1, 0, 0, 0, 0],
"教育系": [1.5, 2, 0, 1.25, 0, 0, 0, 1, 1, 0]
}

# %%
for i in c:
    c[i]=np.dot(grades,c[i])

# %%
def point(department):
    print(c[department])

# %%
interact(point,department=c.keys())
# Out:
# interactive(children=(Dropdown(description='department', options=('土語系', '財政系', '金融系', '國貿系', '會計系', '法律系', '公…
# <function __main__.point(department)>
