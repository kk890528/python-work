# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
import matplotlib as mpl

# %% [markdown]
# [下載微軟正黑體](http://cloud.ziti8.cn/fonts/weiruan/%E5%BE%AE%E8%BD%AF%E6%AD%A3%E9%BB%91%E4%BD%93.ttf)

# %% [markdown]
# # 首先進入matplotlibrc 預設路徑

# %%
mpl.matplotlib_fname()
# Out:
# 'C:\\Users\\Michael\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\matplotlibrc'

# %% [markdown]
# 更改 將font.family與font.serif和font.sans-serif註解(#)移除，並在font.serif，font.sans-serif後方加入Microsoft JhengHei

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 刪除.matplotlib快取資料夾

# %%
C:\Users\您的使用者名稱

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# matplotlib

# %% [markdown]
# # 放入字體至matplotlib指定字體路徑

# %% [markdown]
# 下載微軟正黑體，並放入 C:\Users\您的使用者名稱\Anaconda3\Lib\site-packages\matplotlib\mpl-data\fonts\ttf

# %%
mpl.rc('font', family='Microsoft JhengHei')

# %%
plt.bar(['蔡英文','韓國瑜'],[1450,9.2])
plt.title("測試")
# Out:
# Text(0.5, 1.0, '測試')
