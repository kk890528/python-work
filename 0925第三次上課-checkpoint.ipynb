# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# [炎龍程式碼](https://nbviewer.jupyter.org/github/yenlung/)

# %%
list(range(1,11,2))
# Out:
# [1, 3, 5, 7, 9]

# %%
list("ABCDEF")
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F']

# %%
list(x**2 for x in range(1,11))
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %% [markdown]
# # For 迴圈

# %%
x=list()
for i in range(1,6):
    x.append(i)

# %%
x
# Out:
# [1, 2, 3, 4, 5]

# %%
s=0
for i in range(1,101):
    s=s+i
print(s)
# Out:
# 5050

# %%
# list append

# %%
prices=[1024,399,2000]

# %%
c=34.1415677

# %%
list(np.array(prices)*c)
# Out:
# [34960.9653248, 13622.485512300002, 68283.1354]

# %%
x=list()
for p in prices:
    x.append(p*c)
x
# Out:
# [34960.9653248, 13622.485512300002, 68283.1354]

# %% [markdown]
# # 字串分割

# %%
spam=input('輸入你想買的物品的價格')
# Out:
# 輸入你想買的物品的價格1024,399,20000,600
# [34960.9653248, 13622.485512300002, 682831.354, 20484.94062]

# %%
spam
# Out:
# '1024,399,20000,600'

# %%
spam.split(",")
# Out:
# ['1024', '399', '20000', '600']

# %%
spam=input('輸入你想買的物品的價格')
k=spam.split(",")
kk=list()
for i in k:
    k1=float(i)
    kk.append(round(k1*c,2))
kk
# Out:
# 輸入你想買的物品的價格21,424,12
# [716.97, 14476.02, 409.7]

# %%
round(k1*c,2)
# Out:
# 1911.93

# %%
spam="399 31 3452 62"

# %%
spam.split(" ")
# Out:
# ['399', '31', '3452', '62']

# %%
spam="  399  199 1924 9231"

# %%
spam.split(" ")
# Out:
# ['', '', '399', '', '199', '1924', '9231']

# %%
spam.split()
# Out:
# ['399', '199', '1924', '9231']

# %%
def exchange(p):
    p=float(p)
    return p*c

# %%
exchange("399")
# Out:
# 13622.485512300002

# %% [markdown]
# ### map
# #### map(f,L)
# 把f這函數作用到L list的每一個元素

# %%
L='333   12  9.2    689   34'.split()

# %%
L
# Out:
# ['333', '12', '9.2', '689', '34']

# %%
list(map(exchange,L))
# Out:
# [11369.142044100001,
#  409.69881240000007,
#  314.10242284000003,
#  23523.5401453,
#  1160.8133018]

# %% [markdown]
# ### 緊急用的函數 lambda

# %%
def f(x):
    return x**2

# %%
f(2)
# Out:
# 4

# %%
g=lambda x:x**2

# %%
g(3)
# Out:
# 9

# %%
L
# Out:
# ['333', '12', '9.2', '689', '34']

# %%
list(map(lambda p:float(p)*c,L))
# Out:
# [11369.142044100001,
#  409.69881240000007,
#  314.10242284000003,
#  23523.5401453,
#  1160.8133018]

# %%
egg=[9,4,8,7]

# %%
list(map(lambda m:float(m)*2+1,egg))
# Out:
# [19.0, 9.0, 17.0, 15.0]

# %%
grades=[47,56,60,75]

# %%
list(map(lambda g:np.sqrt(g)*10,grades))
# Out:
# [68.55654600401044, 74.83314773547883, 77.45966692414834, 86.60254037844388]

# %% [markdown]
# ### list comprehension

# %%
L
# Out:
# ['333', '12', '9.2', '689', '34']

# %%
[float(p)*c for p in L]
# Out:
# [11369.142044100001,
#  409.69881240000007,
#  314.10242284000003,
#  23523.5401453,
#  1160.8133018]

# %% [markdown]
# # 合併list

# %%
L
# Out:
# ['333', '12', '9.2', '689', '34']

# %%
s=""
for i in L:
    s=s+i+","
s
# Out:
# '333,12,9.2,689,34,'

# %%
s.rstrip(",")
# Out:
# '333,12,9.2,689,34'

# %%
s[0]
# Out:
# '3'

# %%
s[:-1]
# Out:
# '333,12,9.2,689,34'

# %%
",".join(L)
# Out:
# '333,12,9.2,689,34'

# %% [markdown]
# ### 物件中間的 methon

# %%
egg=[9.2,689,1450,87,54]

# %%
egg.sort()

# %%
egg
# Out:
# [9.2, 54, 87, 689, 1450]

# %%
ham="今天天氣真好"

# %%
ham[3]
# Out:
# '氣'

# %%
ham[::2]
# Out:
# '今天真'

# %%
ham[::-1]
# Out:
# '好真氣天天今'

# %%
from ipywidgets import interact

# %%
def move(n=1):
    print(" "*n+"(0_0)")

# %%
move()
# Out:
#  (0_0)-_-

# %%
interact(move,n=(0,40))
# Out:
# interactive(children=(IntSlider(value=1, description='n', max=40), Output()), _dom_classes=('widget-interact',…
# <function __main__.move(n=1)>

# %%
def move(n=1):
    print(" "*(40-n)+"(0_0)"+" "*n+"-_-"+" "*(40-n))

# %%
print(" "*n+"(0_0)"+"-_-"+"  "*n)
# Out:
#    (0_0)-_-

# %%
n=3
