# %% [markdown]
# # 簡單做兩個函數，判斷是否為數字、文字

# %%
def is_number(str):
  try:
    if str=='NaN':
      return False
    float(str)
    return True
  except ValueError:
    return False
# Out:
# False

# %%
def is_str(str):
    try:
        float(str)
        return False
    except:
        return True
