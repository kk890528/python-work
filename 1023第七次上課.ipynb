# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd

# %% [markdown]
# # array oriented programming

# %%
grades=[56,62,71,45,70]

# %%
new_grades=[]
for i in grades:
    new_grades.append(np.sqrt(i)*10)

# %%
new_grades
# Out:
# [74.83314773547883,
#  78.74007874011811,
#  84.2614977317636,
#  67.0820393249937,
#  83.66600265340756]

# %%
new_grades=[]
for i in grades:
    g=np.sqrt(i)*10+15
    new_grades.append(g)
    print(f"調整後的成績: {g:.2f}")
# Out:
# 調整後的成績: 89.83
# 調整後的成績: 93.74
# 調整後的成績: 99.26
# 調整後的成績: 82.08
# 調整後的成績: 98.67

# %%
new_grades
# Out:
# [89.83314773547883,
#  93.74007874011811,
#  99.2614977317636,
#  82.0820393249937,
#  98.66600265340756]

# %% [markdown]
# ### 換成 array

# %%
arr_grades=np.array(grades)

# %%
arr_grades
# Out:
# array([56, 62, 71, 45, 70])

# %%
np.sqrt(arr_grades)*10+15
# Out:
# array([89.83314774, 93.74007874, 99.26149773, 82.08203932, 98.66600265])

# %%
arr_new_grades=np.sqrt(arr_grades)*10+15

# %%
arr_new_grades
# Out:
# array([89.83314774, 93.74007874, 99.26149773, 82.08203932, 98.66600265])

# %%
arr_new_grades.mean()
# Out:
# 92.71655323715235

# %%
arr_new_grades.std()
# Out:
# 6.33540471768489

# %% [markdown]
# # brocasting

# %%
np.array([3,4,5,9,12])+5
# Out:
# array([ 8,  9, 10, 14, 17])

# %%
mygrades=np.array([89,99,60])

# %%
weights=np.array([0.3,0.4,0.3])

# %%
mygrades*weights
# Out:
# array([26.7, 39.6, 18. ])

# %%
g=mygrades*weights

# %%
g.sum()
# Out:
# 84.3

# %%
np.dot(mygrades,weights)
# Out:
# 84.3

# %%
mygrades @ weights
# Out:
# 84.3

# %% [markdown]
# ### 不同shape 轉換

# %% [markdown]
# #### 0 階的 array(0階 tensor)

# %%
egg=94.87

# %% [markdown]
# #### 1 階的 array(1階 tensor)

# %%
egg=np.array([9,4,8,7])

# %% [markdown]
# #### 2階array(2階tensor)

# %%
A=np.array([[1,2,3],[4,5,6]])

# %%
A
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
B=np.array([3,9,6,12,8,20,1,10,7])

# %%
B.shape
# Out:
# (9,)

# %%
B.reshape(3,3)
# Out:
# array([[ 3,  9,  6],
#        [12,  8, 20],
#        [ 1, 10,  7]])

# %%
B=B.reshape(3,3)

# %%
B.shape=(3,3)

# %%
C=A @ B
C
# Out:
# array([[ 30,  55,  67],
#        [ 78, 136, 166]])

# %%
C[1]
# Out:
# array([ 78, 136, 166])

# %%
C[1,1]
# Out:
# 136

# %%
C[:,2]
# Out:
# array([ 67, 166])

# %%
A.ravel()
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
A
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
X=np.array([3,9,1,3,-5,1,2])

# %% [markdown]
# # 要變成這樣
# [[3],[9],[1]....]

# %%
X.reshape(7,1)
# Out:
# array([[ 3],
#        [ 9],
#        [ 1],
#        [ 3],
#        [-5],
#        [ 1],
#        [ 2]])

# %%
X.reshape(len(X),1)
# Out:
# array([[ 3],
#        [ 9],
#        [ 1],
#        [ 3],
#        [-5],
#        [ 1],
#        [ 2]])

# %% [markdown]
# # array的filter功能

# %%
grades=np.array([59,30,25,65,60,100,85,8])

# %%
passed=np.array([False,False,False,True,True,True,True,False])

# %%
grades[passed]
# Out:
# array([ 65,  60, 100,  85])

# %%
grades[grades>=60]
# Out:
# array([ 65,  60, 100,  85])

# %%
(grades>=60) & (grades<80)
# Out:
# array([False, False, False,  True,  True, False, False, False])

# %%
grades[(grades>=60) & (grades<80)]
# Out:
# array([65, 60])

# %% [markdown]
# ### 畫圖

# %%
pi=np.pi

# %%
x=np.linspace(-2*pi,2*pi,1000)

# %%
y=np.sin(x)

# %%
len(x)==len(y)
# Out:
# True

# %%
plt.plot(x,y)

# %%
plt.scatter(x[y>0],y[y>0],c="#FF235A")
plt.plot(x,y)

# %% [markdown]
# ### 模擬數據集

# %%
x=np.linspace(0,1,50)
y=np.sin(x)

# %%
plt.scatter(x,y)

# %%
noise=0.1 * np.random.randn(50)

# %%
plt.scatter(x,y+noise)

# %% [markdown]
# ### 分類的模擬

# %%
P=np.random.randn(50,2)

# %%
plt.scatter(P[:,0],P[:,1])

# %%
cl=np.random.randint(1,5,50)

# %%
cl
# Out:
# array([1, 4, 2, 1, 1, 4, 4, 4, 3, 3, 3, 4, 4, 3, 2, 1, 1, 1, 3, 3, 2, 2,
#        3, 2, 4, 1, 1, 1, 1, 1, 1, 1, 4, 2, 4, 2, 1, 3, 4, 1, 4, 1, 3, 2,
#        3, 4, 4, 3, 3, 4])

# %%
plt.scatter(P[:,0],P[:,1],c=cl, cmap="Set3",alpha=0.6,s=70)

# %% [markdown]
# ## matplotlin cmap (顏色組合)

# %% [markdown]
# ## SymPy(符號型運算)

# %%
1/2+1/3
# Out:
# 0.8333333333333333

# %%
import sympy as sp

# %%
sp.Rational(1,2)+sp.Rational(1,3)
# Out:
# 5/6

# %%
sp.sympify(1)/2
# Out:
# 1/2

# %%
sp.sympify(1)/2 + sp.sympify(1)/3
# Out:
# 5/6

# %%
sp.S(1)/2 + sp.S(1)/3
# Out:
# 5/6

# %%
from sympy import S

# %%
S(1)/2+S(1)/3
# Out:
# 5/6

# %%
sp.sqrt(3)
# Out:
# sqrt(3)

# %%
sp.pi
# Out:
# pi

# %%
x=sp.symbols("x")

# %%
x
# Out:
# x

# %%
x**2
# Out:
# x**2

# %%
x=sp.symbols(r'\xi')

# %%
x
# Out:
# \xi

# %%
from sympy.abc import x

# %%
x
# Out:
# x

# %%
f=x**2 - 3*x +5

# %%
f
# Out:
# x**2 - 3*x + 5

# %%
sp.diff(f)
# Out:
# 2*x - 3

# %%
sp.integrate(f)
# Out:
# x**3/3 - 3*x**2/2 + 5*x

# %%
f.subs(x,2)
# Out:
# 3

# %%
from sympy.abc import y

# %%
g=3*x*y + 2*x -5*y**2

# %%
g
# Out:
# 3*x*y + 2*x - 5*y**2

# %%
sp.diff(g,x)
# Out:
# 3*y + 2

# %%
sp.integrate(g,x)
# Out:
# x**2*(3*y/2 + 1) - 5*x*y**2

# %% [markdown]
# ### 微分

# %%
sp.diff(sp.log(x),x)
# Out:
# 1/x

# %%
sp.diff(sp.sin(x))
# Out:
# cos(x)

# %%
sp.diff(sp.cos(x))
# Out:
# -sin(x)

# %% [markdown]
# ### 積分

# %%
sp.integrate(sp.log(x))
# Out:
# x*log(x) - x

# %%
sp.integrate(sp.log(x),(x,1,5))
# Out:
# -4 + 5*log(5)

# %% [markdown]
# ### 極限

# %%
sp.limit(sp.sin(x)/x,x,0)
# Out:
# 1

# %% [markdown]
# ###  矩陣

# %%
A=sp.Matrix([[1,2,3],[4,5,7],[7,8,9]])

# %%
A
# Out:
# Matrix([
# [1, 2, 3],
# [4, 5, 7],
# [7, 8, 9]])

# %%
A.rref()
# Out:
# (Matrix([
#  [1, 0, 0],
#  [0, 1, 0],
#  [0, 0, 1]]), (0, 1, 2))

# %%
A.det()
# Out:
# 6

# %%
A.inv()
# Out:
# Matrix([
# [-11/6,  1, -1/6],
# [ 13/6, -2,  5/6],
# [ -1/2,  1, -1/2]])

# %%
f
# Out:
# x**2 - 3*x + 5

# %%
sp.plot(f)

# %%
g=-x**2

# %%
sp.plot(f,g)

# %%
a=7

# %%
sp.isprime(a)
# Out:
# True

# %%
sp.isprime(9487)
# Out:
# False

# %%
sp.prime(1)
# Out:
# 2

# %%
sp.prime(2)
# Out:
# 3

# %%
sp.prime(9487)
# Out:
# 98849

# %%
k=1
i=1
qq=[]
while k!=0:
    
    a=sp.prime(i)
    b=sp.prime(i+1)
    c=b-a
    if c==2:
        qq.append(i)
    i=i+1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-c1916d555ee9> in <module>
#       5
#       6     a=sp.prime(i)
# ----> 7     b=sp.prime(i+1)
#       8     c=b-a
#       9     if c==2:
#
# ~\Anaconda3\lib\site-packages\sympy\ntheory\generate.py in prime(nth)
#     385             a = mid + 1
#     386     n_primes = primepi(a - 1)
# --> 387     while n_primes < n:
#     388         if isprime(a):
#     389             n_primes += 1
#
# ~\Anaconda3\lib\site-packages\sympy\core\numbers.py in __lt__(self, other)
#    2099             raise TypeError("Invalid comparison %s < %s" % (self, other))
#    2100         if other.is_Integer:
# -> 2101             return _sympify(self.p < other.p)
#    2102         return Rational.__lt__(self, other)
#    2103
#
# ~\Anaconda3\lib\site-packages\sympy\core\sympify.py in _sympify(a)
#     415
#     416     """
# --> 417     return sympify(a, strict=True)
#     418
#     419
#
# ~\Anaconda3\lib\site-packages\sympy\core\sympify.py in sympify(a, locals, convert_xor, strict, rational, evaluate)
#     275     if cls in sympy_classes:
#     276         return a
# --> 277     if cls is type(None):
#     278         if strict:
#     279             raise SympifyError(a)
#
# KeyboardInterrupt:

# %%
qq[-1]
# Out:
# 5112

# %%
sp.prime(5113)-sp.prime(5112)
# Out:
# 2

# %%
(sp.pi).n(100)
# Out:
# 1787

# %%
pi=sp.pi
pi.n(100)

# %%
magic=str(pi.n(10000))
# Out:
# 1789

# %%
"1215" in magic
