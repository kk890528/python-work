# %%
1+1
# Out:
# 2

# %%
22*1
# Out:
# 22

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
np.sin(1/2*np.pi)
# Out:
# 1.0

# %%
y=[3,-5,6,7,-8,9]

# %%
plt.plot(y)

# %%
x=[0,0.7,np.sqrt(2),np.pi,7,7.9]

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
x=np.linspace(-10,10,100)

# %%
x
# Out:
# array([-10.        ,  -9.7979798 ,  -9.5959596 ,  -9.39393939,
#         -9.19191919,  -8.98989899,  -8.78787879,  -8.58585859,
#         -8.38383838,  -8.18181818,  -7.97979798,  -7.77777778,
#         -7.57575758,  -7.37373737,  -7.17171717,  -6.96969697,
#         -6.76767677,  -6.56565657,  -6.36363636,  -6.16161616,
#         -5.95959596,  -5.75757576,  -5.55555556,  -5.35353535,
#         -5.15151515,  -4.94949495,  -4.74747475,  -4.54545455,
#         -4.34343434,  -4.14141414,  -3.93939394,  -3.73737374,
#         -3.53535354,  -3.33333333,  -3.13131313,  -2.92929293,
#         -2.72727273,  -2.52525253,  -2.32323232,  -2.12121212,
#         -1.91919192,  -1.71717172,  -1.51515152,  -1.31313131,
#         -1.11111111,  -0.90909091,  -0.70707071,  -0.50505051,
#         -0.3030303 ,  -0.1010101 ,   0.1010101 ,   0.3030303 ,
#          0.50505051,   0.70707071,   0.90909091,   1.11111111,
#          1.31313131,   1.51515152,   1.71717172,   1.91919192,
# ...

# %%
len(x)
# Out:
# 2

# %%
y=np.sin(x)

# %%
plt.plot(x,y)

# %%
plt.xkcd()

# %%
plt.plot(x,y)

# %%
x="7/16","7/23","7/30/","8/5","8/12/","8/19/","8/26","9/2","9/9"

# %%
y=[41.1,38.4,37.8,35.6,35.4,34.2,33.1,31,33.3]

# %%
plt.plot(x,y)
plt.xlabel("time")
plt.ylabel("poll")
plt.title("The change of Korean Fish's Poll for selecting presidency.   Data resource: Apple Daily")
# Out:
# Text(0.5, 1.0, "The change of Korean Fish's Poll for selecting presidency.   Data resource: Apple Daily")

# %%
import matplotlib
matplotlib.matplotlib_fname()
# Out:
# 'C:\\Users\\Michael\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\matplotlibrc'

# %%
plt.xlabel("9月")
# Out:
# Text(0.5, 0, '9月')
